# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt # to draw graphs
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/AI와무역투자론/Data/default_credit_card.csv')
df
# Out:
#        Cust_ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0            1      20000    2          2         1   24      2      2     -1
# 1            2     120000    2          2         2   26     -1      2      0
# 2            3      90000    2          2         2   34      0      0      0
# 3            4      50000    2          2         1   37      0      0      0
# 4            5      50000    1          2         1   57     -1      0     -1
# ...        ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995    29996     220000    1          3         1   39      0      0      0
# 29996    29997     150000    1          3         2   43     -1     -1     -1
# 29997    29998      30000    1          2         2   37      4      3      2
# 29998    29999      80000    1          3         1   41      1     -1      0
# 29999    30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default_YN
# 0             0         0         0         0           1
# 1          1000      1000         0      2000           1
# 2          1000      1000      1000      5000           0
# 3          1200      1100      1069      1000           0
# 4         10000      9000       689       679           0
# ...         ...       ...       ...       ...         ...
# 29995      5003      3047      5000      1000           0
# 29996      8998       129         0         0           0
# 29997     22000      4200      2000      3100           1
# 29998      1178      1926     52964      1804           1
# 29999      1430      1000      1000      1000           1
#
# [30000 rows x 25 columns]

# %% [markdown]
# ## predicator(feature)와 target(label) 정의

# %%
features = ['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE','PAY_0','PAY_2','PAY_3','BILL_AMT1','BILL_AMT2','BILL_AMT3','PAY_AMT1','PAY_AMT2','PAY_AMT3']
label = ['default_YN']

# %% [markdown]
# ## 학습용 데이터와 테스트용 데이터 분리

# %%
from sklearn.model_selection import train_test_split
# Split Data for Logistic Regression
X_train, X_test, y_train, y_test = train_test_split(df[features], df[label], test_size=0.25, random_state=365)
X_train
#y_train
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 6727      220000    1          1         2   29      0      0      0
# 29219      20000    1          2         3   25      0      0      0
# 29528      20000    1          2         1   47      0      0      0
# 1217      340000    2          1         1   30      0      0      0
# 11889      30000    2          2         2   22     -2     -2     -2
# ...          ...  ...        ...       ...  ...    ...    ...    ...
# 8620      350000    1          2         2   36      0      0      0
# 13147     360000    2          1         2   29      0      0      0
# 4897       80000    2          2         1   37      0      0      0
# 2740       70000    2          2         1   28      0      0      0
# 15954      50000    2          1         2   38      2      2      2
#
#        BILL_AMT1  BILL_AMT2  BILL_AMT3  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 6727      216096     189566     183838     10110     12000      5852
# 29219       3855       3150       2862      1040      1225      1000
# 29528      14186      14960      16102      1000      1376      3200
# 1217      351828     280067     259651     30076     25118     20085
# 11889          0          0          0         0         0         0
# ...          ...        ...        ...       ...       ...       ...
# 8620      230738     232382     234254      9503      9015      7511
# 13147     148582      96639      82386     90044     10090     50006
# 4897       57830      55107      51616      2103      2023      1850
# 2740       44230      44348      28978      1747      1272      1212
# 15954      21534      22283      21638      1400         0      1376
#
# [22500 rows x 14 columns]

# %% [markdown]
# ## Support Vector Machine 호출

# %%
from sklearn.svm import SVC

svc_model = SVC()

# %% [markdown]
# ## LogisticRegression 모형을 데이터셋(X_train)에 적합(Fitting)

# %%
fitted_model_svc = svc_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## 학습된 모델(Fitted Model)을 이용하여 새로운 데이터(Test Data)에 대해 예측

# %%
X_test
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 24829      90000    1          2         1   40      0      0      0
# 9495      130000    1          2         2   29     -1     -1     -1
# 29680      50000    1          3         1   47      1      2      0
# 12364     100000    2          3         3   47     -1     -1      2
# 5748      200000    2          1         2   26      0     -1     -1
# ...          ...  ...        ...       ...  ...    ...    ...    ...
# 16715     300000    1          6         1   46      0      0      0
# 19553     140000    2          5         2   25      0      0      0
# 21640     100000    2          2         2   24     -1     -1     -2
# 25493     320000    2          1         2   29      0      0      0
# 3681      430000    2          2         1   30      2      0      0
#
#        BILL_AMT1  BILL_AMT2  BILL_AMT3  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 24829      87190      86135      87247      3068      3335      3319
# 9495        3920       3848        942      4000       942       942
# 29680      16217      15664      16693         0      1586      1300
# 12364        836       1859       1672      2695         0         0
# 5748        6242       1776       3587      1776      3598         0
# ...          ...        ...        ...       ...       ...       ...
# 16715     289299     297003     300153     15000     13274      1010
# 19553      91485      78704      79449      3009      3411      1523
# 21640       3587        660       6010       660      6010      2789
# 25493      42596      43548      33674      1955      2020      1605
# 3681      332721     277080     219739     10896      8123      7522
#
# [7500 rows x 14 columns]

# %% [markdown]
# ## feature값을 기반으로 default_YN을 예측

# %%
predicted_value = fitted_model_svc.predict(X_test)
predicted_value
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pred_value = pd.DataFrame(predicted_value, columns=['predicted_value'])
real_value = y_test.reset_index()
pd.concat([real_value, pred_value],axis=1)
# Out:
#       index  default_YN  predicted_value
# 0     24829           0                0
# 1      9495           0                0
# 2     29680           0                0
# 3     12364           0                0
# 4      5748           0                0
# ...     ...         ...              ...
# 7495  16715           0                0
# 7496  19553           0                0
# 7497  21640           0                0
# 7498  25493           0                0
# 7499   3681           1                0
#
# [7500 rows x 3 columns]
